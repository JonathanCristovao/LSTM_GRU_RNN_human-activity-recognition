# %% [markdown]
# <a href="https://colab.research.google.com/github/JonathanCristovao/LSTM_GRU_RNN_human-activity-recognition/blob/main/LSTM_GRU_RNN_data_aug.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # This notebook was run on google colab

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Import Library

# %%
# !pip install keras_self_attention
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting keras_self_attention
#   Downloading keras-self-attention-0.51.0.tar.gz (11 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from keras_self_attention) (1.21.6)
# Building wheels for collected packages: keras-self-attention
#   Building wheel for keras-self-attention (setup.py) ... done
#   Created wheel for keras-self-attention: filename=keras_self_attention-0.51.0-py3-none-any.whl size=18912 sha256=3088f4940551e8e58ca5391ae11f9e52481177e62f3e6a2e66ed4fc22b4384e3
#   Stored in directory: /root/.cache/pip/wheels/95/b1/a8/5ee00cc137940b2f6fa198212e8f45d813d0e0d9c3a04035a3
# Successfully built keras-self-attention
# Installing collected packages: keras-self-attention
# Successfully installed keras-self-attention-0.51.0

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from scipy import stats
from sklearn import metrics
from sklearn.metrics import classification_report
import glob
import csv
import os
# %matplotlib inline
from keras_self_attention import SeqSelfAttention
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## The dataset used in this notebook can be downloaded here:
# [Click here to download the Dataset](https://www.kaggle.com/datasets/jonathansilva2020/dataset-for-human-activity-recognition-har)

# %%
interesting_dir = "/content/drive/MyDrive/dataset_aug_HAR"
interesting_labels = ['seated','stand','walk','iw_uphill']
save_filename = "activity"

# %% [markdown]
# ## Concate and label the raw data

# %%
def data_concate_label(path,label):
    all_files1 = glob.glob(path + "/*.csv")
    
    li = []

    for filename in all_files1:
        df = pd.read_csv(filename, index_col=None, header=0)
        
        if 'label' in df.columns:
            pass
        else:df['label'] = str(label)
        li.append(df)
    frame = pd.concat(li, axis=0, ignore_index=True)
    if len(df.columns) == 7:#8 :
        new_header =['time','ID_S','Q_I','Q_J','Q_K','Q_R','label']
        #new_header =['date','time','ID_S','Q_I','Q_J','Q_K','Q_R','label']
    
    else :
       
        #new_header =['date','time','ID_S','Q_I','Q_J','Q_K','Q_R','label']
        new_header =['time','ID_S','Q_I','Q_J','Q_K','Q_R','label']

    frame = frame[:160000]#frame[:16000]
    
    print(frame.shape)
    print(len(df.columns))
    frame.to_csv("/content/drive/MyDrive/dataset_aug_HAR/activity_"+str(label)+".csv",index = False,header=new_header)

# %%
path1 = "/content/drive/MyDrive/dataset_aug_HAR/seated"
label1 = "seated"
path2 = "/content/drive/MyDrive/dataset_aug_HAR/stand"
label2 = "stand"
path3 = "/content/drive/MyDrive/dataset_aug_HAR/walk"
label3 = "walk"
path4 = "/content/drive/MyDrive/dataset_aug_HAR/wuphill"
label4 = "iw_uphill"
data_concate_label(path1,label1)
data_concate_label(path2,label2)
data_concate_label(path3,label3)
data_concate_label(path4,label4)
# Out:
# (108040, 7)
# 7
# (90320, 7)
# 7
# (80480, 7)
# 7
# (26400, 7)
# 7

# %% [markdown]
# ## Concate all data into one .csv file

# %%
import copy

df = pd.DataFrame()
for i in range(len(interesting_labels)):
    df_tmp = pd.read_csv(interesting_dir+"/"+save_filename+"_"+interesting_labels[i]+'.csv',header = 0)
    df = pd.concat([df, df_tmp])
print(len(df.columns))

drop_list = ['time']#['date','time']

df = df.drop(drop_list, axis=1)
df = df.dropna()

all_data_filename = "total.csv"
df.to_csv(interesting_dir+all_data_filename)

df.head()
# Out:
# 7
#    ID_S      Q_I      Q_J      Q_K      Q_R   label
# 0     1  0.28850  0.58100 -0.11875  0.75050  seated
# 1     3  0.00800  0.01375 -0.01150  0.01675  seated
# 2     4 -0.04975  0.02825  0.70125  0.70875  seated
# 3     2  0.01225  0.06875 -0.11875  0.75050  seated
# 4     2  0.01225  0.06875 -0.11875  0.75050  seated

# %% [markdown]
# ## Feature correlation

# %%
df_cor = copy.deepcopy(df) 

features = df_cor.columns[0:-1]
df_cor["label"] = pd.factorize(df_cor.label)[0]
traindf = pd.DataFrame(df_cor,columns=features)

feature_name = list(traindf.columns)
print(feature_name)
y = df_cor['label']
X = traindf.copy()
X.isna().sum()
# Out:
# ['ID_S', 'Q_I', 'Q_J', 'Q_K', 'Q_R']
# ID_S    0
# Q_I     0
# Q_J     0
# Q_K     0
# Q_R     0
# dtype: int64

# %%
from sklearn.ensemble import ExtraTreesClassifier
import matplotlib.pyplot as plt
model = ExtraTreesClassifier()
model.fit(X,y)
print(model.feature_importances_) 
#plot graph of feature importances for better visualization
feat_importances = pd.Series(model.feature_importances_, index=X.columns)
feat_importances.nlargest(10).plot(kind='barh')
plt.show()
# Out:
# [0.12414785 0.1392944  0.1999109  0.24330777 0.29333909]

# %%
#get correlations of each features in dataset
#corrmat = df_cor.corr()
#top_corr_features = corrmat.index
#plt.figure(figsize=(20,20))
#plot heat map
#g=sns.heatmap(df_cor[top_corr_features].corr(),annot=True,cmap="RdYlGn")

# %%
num_feats= len(feature_name)
X.columns.tolist()
# Out:
# ['ID_S', 'Q_I', 'Q_J', 'Q_K', 'Q_R']

# %%
def cor_selector(X, y,num_feats):
    cor_list = []
    feature_name = X.columns.tolist()
    
    # calculate the correlation with y for each feature
    for i in X.columns.tolist():
        cor = np.corrcoef(X[i], y)[0, 1]
        cor_list.append(cor)
        
    # replace NaN with 0
    cor_list = [0 if np.isnan(i) else i for i in cor_list]
    
    # feature name
    cor_feature = X.iloc[:,np.argsort(np.abs(cor_list))[-num_feats:]].columns.tolist()
   
    # feature selection? 0 for not select, 1 for select
    cor_support = [True if i in cor_feature else False for i in feature_name]

    return cor_support, cor_feature, cor_list

cor_support, cor_feature, cor_list = cor_selector(X, y,num_feats)
cor_val=[abs(x) for x in cor_list]
cor_result = dict(zip(cor_feature, cor_val))
myDict = {key:val for key, val in cor_result.items() if val > 0}
{k: v for k, v in sorted(myDict.items(),reverse=True, key=lambda item: item[1])}
# Out:
# {'Q_K': 0.5029824119693794,
#  'Q_R': 0.3917860464849101,
#  'Q_I': 0.1350155586668575,
#  'Q_J': 0.01281059817835668,
#  'ID_S': 0.009470907652924986}

# %%
activities = df['label'].value_counts().index
activities
# Out:
# Index(['seated', 'stand', 'walk', 'iw_uphill'], dtype='object')

# %% [markdown]
# ## Split training and testing data

# %%
def train_test_split(label, ratio):
    split_point = int(len(df[df.label == label]) * ratio)
    return (df[df.label == label].iloc[:split_point, :], df[df.label == label].iloc[split_point:, :])

split_ratio = 0.8
train_data = pd.DataFrame([])
test_data = pd.DataFrame([])

for i in range(len(interesting_labels)):
    (train, test) = train_test_split(interesting_labels[i], split_ratio)
    train_data = pd.concat([train_data, train])
    test_data = pd.concat([test_data, test])

print("Number of train samples: ", len(train_data))
print("Number of test samples: ", len(test_data))


train_label = train_data['label'].to_frame()
test_label = test_data['label'].to_frame()
# Out:
# Number of train samples:  241648
# Number of test samples:  60412

# %% [markdown]
# ## Data Segmentation (Sliding Window)

# %%
N_TIME_STEPS = 5 #sliding window length # 10 #120
STEP = 2 # Sliding window step size 20
N_FEATURES = 5

def generate_sequence(x, y, n_time_steps, step):
    
    segments = []
    labels = []
    for i in range(0, len(x) - n_time_steps, step):

        ID_S = x['ID_S'].values[i: i + n_time_steps]
        Q_I = x['Q_I'].values[i: i + n_time_steps]
        Q_J = x['Q_J'].values[i: i + n_time_steps]
        Q_K = x['Q_K'].values[i: i + n_time_steps]
        Q_R = x['Q_R'].values[i: i + n_time_steps]
     
        label = stats.mode(y['label'][i: i + n_time_steps])[0][0]
        segments.append([ID_S, Q_I, Q_J, Q_K, Q_R])
        labels.append(label)
        
    return segments, labels

train_X, train_y = generate_sequence(train_data, train_label, N_TIME_STEPS, STEP)
test_X, test_y = generate_sequence(test_data, test_label, N_TIME_STEPS, STEP)

# %%
# reshape input segments and one-hot encode labels
def reshape_segments(x, y, n_time_steps, n_features):
    
    x_reshaped = np.asarray(x, dtype= np.float32).reshape(-1, n_time_steps, n_features)
    y_reshaped = np.asarray(pd.get_dummies(y), dtype = np.float32)
    return x_reshaped, y_reshaped

X_train, y_train = reshape_segments(train_X, train_y, N_TIME_STEPS, N_FEATURES)
X_test, y_test = reshape_segments(test_X, test_y, N_TIME_STEPS, N_FEATURES)

# %%
#y_test

# %% [markdown]
# ## Import DL Library

# %%
from keras.regularizers import l2
from keras.models import Sequential, load_model
from keras.layers import Dense, LSTM, Flatten, Bidirectional
from tensorflow.keras.layers import Attention
from keras.layers import Conv2D, MaxPooling2D, Dropout
from keras import optimizers
from keras import backend as K
from tensorflow.python.tools import freeze_graph
from tensorflow.python.tools import optimize_for_inference_lib

from keras.callbacks import ModelCheckpoint, LearningRateScheduler, TensorBoard, EarlyStopping, ReduceLROnPlateau
N_CLASSES = 4
L2 = 0.00001

# %% [markdown]
# ## LSTM Model

# %%
# LSTM model
from keras.backend import clear_session
filepath = 'har_model_lstm_2021.h5'

clear_session()
model = Sequential()
model.add(Bidirectional(LSTM(200, return_sequences=True,kernel_initializer='orthogonal',
                             kernel_regularizer=l2(L2), recurrent_regularizer=l2(L2),
                             bias_regularizer=l2(L2),name="LSTM_1"),
                             input_shape=(N_TIME_STEPS, N_FEATURES)))

model.add(Flatten(name='Flatten'))
model.add(Dense(128, activation='relu', kernel_regularizer=l2(L2), bias_regularizer=l2(L2), name="Dense_3"))
model.add(Dropout(0.2))
model.add(Dense(N_CLASSES, activation='softmax', kernel_regularizer=l2(L2), bias_regularizer=l2(L2), name="Dense_4"))


model.summary()

checkpoint = ModelCheckpoint(filepath=filepath,
                             monitor='val_loss',
                             verbose=1,
                             save_best_only=True)
stop = EarlyStopping(monitor='val_loss', patience =5,
                      verbose=0, mode='auto', baseline=None, 
                      restore_best_weights=False)
reduce =  ReduceLROnPlateau(monitor='val_loss',
                    factor=0.5,
                    patience=2,
                    verbose=1)
callbacks = [checkpoint,stop]

model.compile(optimizer="adam",loss='categorical_crossentropy',metrics=['accuracy'])

BATCH_SIZE =64
N_EPOCHS = 300

lstm = model.fit(X_train, y_train,
          batch_size=BATCH_SIZE, shuffle=True,epochs=N_EPOCHS,callbacks=callbacks,
          validation_data=(X_test, y_test))
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional (Bidirectiona  (None, 5, 400)           329600
#  l)
#
#  Flatten (Flatten)           (None, 2000)              0
#
#  Dense_3 (Dense)             (None, 128)               256128
#
#  dropout (Dropout)           (None, 128)               0
#
#  Dense_4 (Dense)             (None, 4)                 516
#
# =================================================================
# Total params: 586,244
# Trainable params: 586,244
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/300
# 1886/1888 [============================>.] - ETA: 0s - loss: 0.1707 - accuracy: 0.9516
# Epoch 1: val_loss improved from inf to 0.06909, saving model to har_model_lstm_2021.h5
# 1888/1888 [==============================] - 23s 11ms/step - loss: 0.1706 - accuracy: 0.9517 - val_loss: 0.0691 - val_accuracy: 0.9900
# Epoch 2/300
# 1888/1888 [==============================] - ETA: 0s - loss: 0.0851 - accuracy: 0.9828
# Epoch 2: val_loss improved from 0.06909 to 0.04890, saving model to har_model_lstm_2021.h5
# 1888/1888 [==============================] - 14s 8ms/step - loss: 0.0851 - accuracy: 0.9828 - val_loss: 0.0489 - val_accuracy: 0.9939
# Epoch 3/300
# 1881/1888 [============================>.] - ETA: 0s - loss: 0.0671 - accuracy: 0.9866
# Epoch 3: val_loss improved from 0.04890 to 0.03495, saving model to har_model_lstm_2021.h5
# 1888/1888 [==============================] - 14s 7ms/step - loss: 0.0670 - accuracy: 0.9866 - val_loss: 0.0349 - val_accuracy: 0.9945
# Epoch 4/300
# 1881/1888 [============================>.] - ETA: 0s - loss: 0.0579 - accuracy: 0.9881
# Epoch 4: val_loss improved from 0.03495 to 0.02957, saving model to har_model_lstm_2021.h5
# 1888/1888 [==============================] - 14s 7ms/step - loss: 0.0579 - accuracy: 0.9881 - val_loss: 0.0296 - val_accuracy: 0.9959
# Epoch 5/300
# 1885/1888 [============================>.] - ETA: 0s - loss: 0.0507 - accuracy: 0.9897
# Epoch 5: val_loss improved from 0.02957 to 0.02878, saving model to har_model_lstm_2021.h5
# 1888/1888 [==============================] - 15s 8ms/step - loss: 0.0507 - accuracy: 0.9898 - val_loss: 0.0288 - val_accuracy: 0.9968
# Epoch 6/300
# 1885/1888 [============================>.] - ETA: 0s - loss: 0.0454 - accuracy: 0.9910
# Epoch 6: val_loss improved from 0.02878 to 0.02315, saving model to har_model_lstm_2021.h5
# 1888/1888 [==============================] - 15s 8ms/step - loss: 0.0454 - accuracy: 0.9911 - val_loss: 0.0232 - val_accuracy: 0.9965
# Epoch 7/300
# 1882/1888 [============================>.] - ETA: 0s - loss: 0.0418 - accuracy: 0.9919
# Epoch 7: val_loss did not improve from 0.02315
# 1888/1888 [==============================] - 15s 8ms/step - loss: 0.0418 - accuracy: 0.9919 - val_loss: 0.0373 - val_accuracy: 0.9930
# Epoch 8/300
# 1886/1888 [============================>.] - ETA: 0s - loss: 0.0376 - accuracy: 0.9930
# Epoch 8: val_loss improved from 0.02315 to 0.02131, saving model to har_model_lstm_2021.h5
# 1888/1888 [==============================] - 14s 7ms/step - loss: 0.0377 - accuracy: 0.9930 - val_loss: 0.0213 - val_accuracy: 0.9974
# Epoch 9/300
# 1883/1888 [============================>.] - ETA: 0s - loss: 0.0345 - accuracy: 0.9940
# Epoch 9: val_loss did not improve from 0.02131
# 1888/1888 [==============================] - 14s 7ms/step - loss: 0.0345 - accuracy: 0.9940 - val_loss: 0.0234 - val_accuracy: 0.9964
# Epoch 10/300
# 1884/1888 [============================>.] - ETA: 0s - loss: 0.0314 - accuracy: 0.9945
# Epoch 10: val_loss did not improve from 0.02131
# 1888/1888 [==============================] - 15s 8ms/step - loss: 0.0314 - accuracy: 0.9945 - val_loss: 0.0284 - val_accuracy: 0.9965
# Epoch 11/300
# 1884/1888 [============================>.] - ETA: 0s - loss: 0.0294 - accuracy: 0.9952
# Epoch 11: val_loss did not improve from 0.02131
# 1888/1888 [==============================] - 14s 7ms/step - loss: 0.0294 - accuracy: 0.9952 - val_loss: 0.0214 - val_accuracy: 0.9980
# Epoch 12/300
# 1884/1888 [============================>.] - ETA: 0s - loss: 0.0273 - accuracy: 0.9956
# Epoch 12: val_loss improved from 0.02131 to 0.01716, saving model to har_model_lstm_2021.h5
# 1888/1888 [==============================] - 14s 8ms/step - loss: 0.0273 - accuracy: 0.9956 - val_loss: 0.0172 - val_accuracy: 0.9987
# Epoch 13/300
# 1885/1888 [============================>.] - ETA: 0s - loss: 0.0254 - accuracy: 0.9962
# Epoch 13: val_loss did not improve from 0.01716
# 1888/1888 [==============================] - 14s 7ms/step - loss: 0.0254 - accuracy: 0.9962 - val_loss: 0.0207 - val_accuracy: 0.9988
# Epoch 14/300
# 1888/1888 [==============================] - ETA: 0s - loss: 0.0247 - accuracy: 0.9962
# Epoch 14: val_loss did not improve from 0.01716
# 1888/1888 [==============================] - 15s 8ms/step - loss: 0.0247 - accuracy: 0.9962 - val_loss: 0.0181 - val_accuracy: 0.9992
# Epoch 15/300
# 1887/1888 [============================>.] - ETA: 0s - loss: 0.0228 - accuracy: 0.9969
# Epoch 15: val_loss did not improve from 0.01716
# 1888/1888 [==============================] - 14s 7ms/step - loss: 0.0228 - accuracy: 0.9969 - val_loss: 0.0250 - val_accuracy: 0.9955
# Epoch 16/300
# 1883/1888 [============================>.] - ETA: 0s - loss: 0.0213 - accuracy: 0.9971
# Epoch 16: val_loss did not improve from 0.01716
# 1888/1888 [==============================] - 14s 7ms/step - loss: 0.0213 - accuracy: 0.9971 - val_loss: 0.0192 - val_accuracy: 0.9983
# Epoch 17/300
# 1882/1888 [============================>.] - ETA: 0s - loss: 0.0213 - accuracy: 0.9973
# Epoch 17: val_loss did not improve from 0.01716
# 1888/1888 [==============================] - 14s 7ms/step - loss: 0.0213 - accuracy: 0.9973 - val_loss: 0.0210 - val_accuracy: 0.9974

# %%
# use LSTM model to predict

y_pred_ohe = model.predict(X_test)
y_pred_labels = np.argmax(y_pred_ohe, axis=1)
y_true_labels = np.argmax(y_test, axis=1)
confusion_matrix = metrics.confusion_matrix(y_true=y_true_labels, y_pred=y_pred_labels)
print(y_true_labels)
LABELS = ['seated', 'stand','walk','iwuphill']

plt.figure(figsize=(8, 6))
sns.set(style='whitegrid', palette='muted', font_scale=1.5)
sns.heatmap(confusion_matrix, xticklabels=LABELS, yticklabels=LABELS, annot=True, fmt="d");
plt.title("Confusion matrix - LSTM")
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.show();
# Out:
# 944/944 [==============================] - 3s 3ms/step
# [1 1 1 ... 0 0 0]

# %%
predIdxs = model.predict(X_test, batch_size=BATCH_SIZE)
predIdxs = np.argmax(predIdxs, axis=1)
# Out:
# 472/472 [==============================] - 1s 3ms/step

# %%
## show a classification report
print(classification_report(y_test.argmax(axis=1), predIdxs,
	target_names=['seated', 'stand','walk','iwuphill']))
# Out:
#               precision    recall  f1-score   support
#
#       seated       0.99      1.00      0.99      2321
#        stand       1.00      1.00      1.00     10803
#         walk       1.00      1.00      1.00      9032
#     iwuphill       1.00      1.00      1.00      8048
#
#     accuracy                           1.00     30204
#    macro avg       1.00      1.00      1.00     30204
# weighted avg       1.00      1.00      1.00     30204

# %%
plt.plot(lstm.history['accuracy'])
plt.plot(lstm.history['val_accuracy'])
plt.title('model accuracy - LSTM')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.ylim(0,1)
plt.legend(['train', 'val'], loc='best')
plt.show()

plt.plot(lstm.history['loss'])
plt.plot(lstm.history['val_loss'])
plt.title('model loss - LSTM')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='best')
plt.show()

# %% [markdown]
# ## Save the model into .pb file

# %%
# Save LSTM model

#output_node_name = "Dense_2/Softmax"
#MODEL_LSTM = str(N_TIME_STEPS)+"_"+str(STEP)+"_"+str(N_FEATURES)+"_"+str(N_CLASSES)+"_nomagnew"

#tf.train.write_graph(K.get_session().graph_def, './models/LSTM/', \     MODEL_LSTM + '_graph.pbtxt')
#saver = tf.train.Saver()
#saver.save(K.get_session(), './models/LSTM/' + MODEL_LSTM + '.chkp')

#freeze_graph.freeze_graph('./models/LSTM/' +MODEL_LSTM+ '_graph.pbtxt', None, \
#   False, './models/LSTM/' + MODEL_LSTM+ '.chkp', output_node_name, \
#   "save/restore_all", "save/Const:0", \
#    './models/LSTM/' +MODEL_LSTM + '.pb', True, "")

# %% [markdown]
# # GRU Model

# %%
from keras.layers import GRU

# %%
# GRU model
from keras.backend import clear_session
filepath = 'har_model_gru.h5'

clear_session()
model = Sequential()
model.add(Bidirectional(GRU(200, return_sequences=True,kernel_initializer='orthogonal',
                             kernel_regularizer=l2(L2), recurrent_regularizer=l2(L2),
                             bias_regularizer=l2(L2),name="LSTM_1"),
                             input_shape=(N_TIME_STEPS, N_FEATURES)))

model.add(Flatten(name='Flatten'))
model.add(Dense(128, activation='relu', kernel_regularizer=l2(L2), bias_regularizer=l2(L2), name="Dense_3"))
model.add(Dropout(0.2))
model.add(Dense(N_CLASSES, activation='softmax', kernel_regularizer=l2(L2), bias_regularizer=l2(L2), name="Dense_4"))


model.summary()

checkpoint = ModelCheckpoint(filepath=filepath,
                             monitor='val_loss',
                             verbose=1,
                             save_best_only=True)
stop = EarlyStopping(monitor='val_loss', patience =5,
                      verbose=0, mode='auto', baseline=None, 
                      restore_best_weights=False)
reduce =  ReduceLROnPlateau(monitor='val_loss',
                    factor=0.5,
                    patience=2,
                    verbose=1)
callbacks = [checkpoint,stop]

model.compile(optimizer="adam",loss='categorical_crossentropy',metrics=['accuracy'])

BATCH_SIZE =64
N_EPOCHS = 300

lstm = model.fit(X_train, y_train,
          batch_size=BATCH_SIZE, shuffle=True,epochs=N_EPOCHS,callbacks=callbacks,
          validation_data=(X_test, y_test))
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional (Bidirectiona  (None, 5, 400)           248400
#  l)
#
#  Flatten (Flatten)           (None, 2000)              0
#
#  Dense_3 (Dense)             (None, 128)               256128
#
#  dropout (Dropout)           (None, 128)               0
#
#  Dense_4 (Dense)             (None, 4)                 516
#
# =================================================================
# Total params: 505,044
# Trainable params: 505,044
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/300
# 1881/1888 [============================>.] - ETA: 0s - loss: 0.1465 - accuracy: 0.9594
# Epoch 1: val_loss improved from inf to 0.05732, saving model to har_model_gru.h5
# 1888/1888 [==============================] - 17s 7ms/step - loss: 0.1463 - accuracy: 0.9595 - val_loss: 0.0573 - val_accuracy: 0.9855
# Epoch 2/300
# 1885/1888 [============================>.] - ETA: 0s - loss: 0.0796 - accuracy: 0.9824
# Epoch 2: val_loss improved from 0.05732 to 0.03664, saving model to har_model_gru.h5
# 1888/1888 [==============================] - 13s 7ms/step - loss: 0.0796 - accuracy: 0.9824 - val_loss: 0.0366 - val_accuracy: 0.9929
# Epoch 3/300
# 1887/1888 [============================>.] - ETA: 0s - loss: 0.0641 - accuracy: 0.9869
# Epoch 3: val_loss did not improve from 0.03664
# 1888/1888 [==============================] - 13s 7ms/step - loss: 0.0640 - accuracy: 0.9869 - val_loss: 0.0461 - val_accuracy: 0.9900
# Epoch 4/300
# 1886/1888 [============================>.] - ETA: 0s - loss: 0.0550 - accuracy: 0.9887
# Epoch 4: val_loss improved from 0.03664 to 0.02828, saving model to har_model_gru.h5
# 1888/1888 [==============================] - 14s 8ms/step - loss: 0.0550 - accuracy: 0.9887 - val_loss: 0.0283 - val_accuracy: 0.9959
# Epoch 5/300
# 1886/1888 [============================>.] - ETA: 0s - loss: 0.0490 - accuracy: 0.9902
# Epoch 5: val_loss improved from 0.02828 to 0.02567, saving model to har_model_gru.h5
# 1888/1888 [==============================] - 13s 7ms/step - loss: 0.0490 - accuracy: 0.9902 - val_loss: 0.0257 - val_accuracy: 0.9958
# Epoch 6/300
# 1886/1888 [============================>.] - ETA: 0s - loss: 0.0448 - accuracy: 0.9911
# Epoch 6: val_loss improved from 0.02567 to 0.02493, saving model to har_model_gru.h5
# 1888/1888 [==============================] - 13s 7ms/step - loss: 0.0448 - accuracy: 0.9911 - val_loss: 0.0249 - val_accuracy: 0.9960
# Epoch 7/300
# 1885/1888 [============================>.] - ETA: 0s - loss: 0.0384 - accuracy: 0.9932
# Epoch 7: val_loss did not improve from 0.02493
# 1888/1888 [==============================] - 14s 7ms/step - loss: 0.0384 - accuracy: 0.9932 - val_loss: 0.0258 - val_accuracy: 0.9967
# Epoch 8/300
# 1882/1888 [============================>.] - ETA: 0s - loss: 0.0359 - accuracy: 0.9937
# Epoch 8: val_loss improved from 0.02493 to 0.02318, saving model to har_model_gru.h5
# 1888/1888 [==============================] - 13s 7ms/step - loss: 0.0360 - accuracy: 0.9937 - val_loss: 0.0232 - val_accuracy: 0.9983
# Epoch 9/300
# 1885/1888 [============================>.] - ETA: 0s - loss: 0.0327 - accuracy: 0.9943
# Epoch 9: val_loss did not improve from 0.02318
# 1888/1888 [==============================] - 13s 7ms/step - loss: 0.0327 - accuracy: 0.9943 - val_loss: 0.0289 - val_accuracy: 0.9973
# Epoch 10/300
# 1886/1888 [============================>.] - ETA: 0s - loss: 0.0302 - accuracy: 0.9952
# Epoch 10: val_loss did not improve from 0.02318
# 1888/1888 [==============================] - 13s 7ms/step - loss: 0.0302 - accuracy: 0.9952 - val_loss: 0.0659 - val_accuracy: 0.9829
# Epoch 11/300
# 1885/1888 [============================>.] - ETA: 0s - loss: 0.0281 - accuracy: 0.9953
# Epoch 11: val_loss improved from 0.02318 to 0.02303, saving model to har_model_gru.h5
# 1888/1888 [==============================] - 13s 7ms/step - loss: 0.0282 - accuracy: 0.9953 - val_loss: 0.0230 - val_accuracy: 0.9979
# Epoch 12/300
# 1886/1888 [============================>.] - ETA: 0s - loss: 0.0255 - accuracy: 0.9963
# Epoch 12: val_loss improved from 0.02303 to 0.01963, saving model to har_model_gru.h5
# 1888/1888 [==============================] - 13s 7ms/step - loss: 0.0255 - accuracy: 0.9963 - val_loss: 0.0196 - val_accuracy: 0.9989
# Epoch 13/300
# 1882/1888 [============================>.] - ETA: 0s - loss: 0.0255 - accuracy: 0.9962
# Epoch 13: val_loss did not improve from 0.01963
# 1888/1888 [==============================] - 14s 7ms/step - loss: 0.0256 - accuracy: 0.9962 - val_loss: 0.0212 - val_accuracy: 0.9978
# Epoch 14/300
# 1883/1888 [============================>.] - ETA: 0s - loss: 0.0232 - accuracy: 0.9968
# Epoch 14: val_loss improved from 0.01963 to 0.01758, saving model to har_model_gru.h5
# 1888/1888 [==============================] - 14s 7ms/step - loss: 0.0232 - accuracy: 0.9968 - val_loss: 0.0176 - val_accuracy: 0.9991
# Epoch 15/300
# 1886/1888 [============================>.] - ETA: 0s - loss: 0.0229 - accuracy: 0.9969
# Epoch 15: val_loss did not improve from 0.01758
# 1888/1888 [==============================] - 13s 7ms/step - loss: 0.0229 - accuracy: 0.9969 - val_loss: 0.0178 - val_accuracy: 0.9981
# Epoch 16/300
# 1885/1888 [============================>.] - ETA: 0s - loss: 0.0221 - accuracy: 0.9972
# Epoch 16: val_loss did not improve from 0.01758
# 1888/1888 [==============================] - 13s 7ms/step - loss: 0.0221 - accuracy: 0.9972 - val_loss: 0.0184 - val_accuracy: 0.9994
# Epoch 17/300
# 1888/1888 [==============================] - ETA: 0s - loss: 0.0200 - accuracy: 0.9979
# Epoch 17: val_loss did not improve from 0.01758
# 1888/1888 [==============================] - 13s 7ms/step - loss: 0.0200 - accuracy: 0.9979 - val_loss: 0.0206 - val_accuracy: 0.9974
# Epoch 18/300
# 1888/1888 [==============================] - ETA: 0s - loss: 0.0213 - accuracy: 0.9975
# Epoch 18: val_loss improved from 0.01758 to 0.01679, saving model to har_model_gru.h5
# 1888/1888 [==============================] - 13s 7ms/step - loss: 0.0213 - accuracy: 0.9975 - val_loss: 0.0168 - val_accuracy: 0.9986
# Epoch 19/300
# 1885/1888 [============================>.] - ETA: 0s - loss: 0.0188 - accuracy: 0.9980
# Epoch 19: val_loss did not improve from 0.01679
# 1888/1888 [==============================] - 13s 7ms/step - loss: 0.0188 - accuracy: 0.9980 - val_loss: 0.0183 - val_accuracy: 0.9985
# Epoch 20/300
# 1885/1888 [============================>.] - ETA: 0s - loss: 0.0179 - accuracy: 0.9982
# Epoch 20: val_loss did not improve from 0.01679
# 1888/1888 [==============================] - 13s 7ms/step - loss: 0.0180 - accuracy: 0.9982 - val_loss: 0.0203 - val_accuracy: 0.9976
# Epoch 21/300
# 1886/1888 [============================>.] - ETA: 0s - loss: 0.0186 - accuracy: 0.9981
# Epoch 21: val_loss improved from 0.01679 to 0.01527, saving model to har_model_gru.h5
# 1888/1888 [==============================] - 13s 7ms/step - loss: 0.0186 - accuracy: 0.9981 - val_loss: 0.0153 - val_accuracy: 0.9993
# Epoch 22/300
# 1887/1888 [============================>.] - ETA: 0s - loss: 0.0178 - accuracy: 0.9982
# Epoch 22: val_loss did not improve from 0.01527
# 1888/1888 [==============================] - 14s 7ms/step - loss: 0.0178 - accuracy: 0.9982 - val_loss: 0.0180 - val_accuracy: 0.9986
# Epoch 23/300
# 1885/1888 [============================>.] - ETA: 0s - loss: 0.0172 - accuracy: 0.9984
# Epoch 23: val_loss did not improve from 0.01527
# 1888/1888 [==============================] - 13s 7ms/step - loss: 0.0172 - accuracy: 0.9984 - val_loss: 0.0174 - val_accuracy: 0.9990
# Epoch 24/300
# 1885/1888 [============================>.] - ETA: 0s - loss: 0.0162 - accuracy: 0.9989
# Epoch 24: val_loss did not improve from 0.01527
# 1888/1888 [==============================] - 13s 7ms/step - loss: 0.0162 - accuracy: 0.9989 - val_loss: 0.0167 - val_accuracy: 0.9986
# Epoch 25/300
# 1883/1888 [============================>.] - ETA: 0s - loss: 0.0192 - accuracy: 0.9980
# Epoch 25: val_loss did not improve from 0.01527
# 1888/1888 [==============================] - 13s 7ms/step - loss: 0.0192 - accuracy: 0.9980 - val_loss: 0.0182 - val_accuracy: 0.9982
# Epoch 26/300
# 1887/1888 [============================>.] - ETA: 0s - loss: 0.0153 - accuracy: 0.9989
# Epoch 26: val_loss improved from 0.01527 to 0.01343, saving model to har_model_gru.h5
# 1888/1888 [==============================] - 13s 7ms/step - loss: 0.0153 - accuracy: 0.9989 - val_loss: 0.0134 - val_accuracy: 0.9998
# Epoch 27/300
# 1885/1888 [============================>.] - ETA: 0s - loss: 0.0163 - accuracy: 0.9986
# Epoch 27: val_loss did not improve from 0.01343
# 1888/1888 [==============================] - 13s 7ms/step - loss: 0.0163 - accuracy: 0.9986 - val_loss: 0.0156 - val_accuracy: 0.9995
# Epoch 28/300
# 1882/1888 [============================>.] - ETA: 0s - loss: 0.0157 - accuracy: 0.9987
# Epoch 28: val_loss did not improve from 0.01343
# 1888/1888 [==============================] - 13s 7ms/step - loss: 0.0157 - accuracy: 0.9986 - val_loss: 0.0163 - val_accuracy: 0.9990
# Epoch 29/300
# 1883/1888 [============================>.] - ETA: 0s - loss: 0.0159 - accuracy: 0.9987
# Epoch 29: val_loss did not improve from 0.01343
# 1888/1888 [==============================] - 13s 7ms/step - loss: 0.0159 - accuracy: 0.9987 - val_loss: 0.0137 - val_accuracy: 0.9995
# Epoch 30/300
# 1881/1888 [============================>.] - ETA: 0s - loss: 0.0149 - accuracy: 0.9988
# Epoch 30: val_loss did not improve from 0.01343
# 1888/1888 [==============================] - 13s 7ms/step - loss: 0.0149 - accuracy: 0.9988 - val_loss: 0.0167 - val_accuracy: 0.9981
# Epoch 31/300
# 1888/1888 [==============================] - ETA: 0s - loss: 0.0154 - accuracy: 0.9988
# Epoch 31: val_loss did not improve from 0.01343
# 1888/1888 [==============================] - 13s 7ms/step - loss: 0.0154 - accuracy: 0.9988 - val_loss: 0.0298 - val_accuracy: 0.9953

# %%
# GRU model to predict

y_pred_ohe = model.predict(X_test)
y_pred_labels = np.argmax(y_pred_ohe, axis=1)
y_true_labels = np.argmax(y_test, axis=1)
confusion_matrix = metrics.confusion_matrix(y_true=y_true_labels, y_pred=y_pred_labels)
print(y_true_labels)
LABELS = ['seated', 'stand','walk','iwuphill']

plt.figure(figsize=(8, 6))
sns.set(style='whitegrid', palette='muted', font_scale=1.5)
sns.heatmap(confusion_matrix, xticklabels=LABELS, yticklabels=LABELS, annot=True, fmt="d");
plt.title("Confusion matrix- GRU")
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.show();
# Out:
# 944/944 [==============================] - 3s 2ms/step
# [1 1 1 ... 0 0 0]

# %%
predIdxs = model.predict(X_test, batch_size=BATCH_SIZE)
predIdxs = np.argmax(predIdxs, axis=1)

# show a classification report
print(classification_report(y_test.argmax(axis=1), predIdxs,
	target_names=['seated', 'stand','walk','iwuphill']))
# Out:
# 472/472 [==============================] - 1s 2ms/step
#               precision    recall  f1-score   support
#
#       seated       1.00      0.97      0.98      2321
#        stand       1.00      0.99      1.00     10803
#         walk       0.99      1.00      1.00      9032
#     iwuphill       0.99      1.00      1.00      8048
#
#     accuracy                           1.00     30204
#    macro avg       1.00      0.99      0.99     30204
# weighted avg       1.00      1.00      1.00     30204

# %%
plt.plot(lstm.history['accuracy'])
plt.plot(lstm.history['val_accuracy'])
plt.title('model accuracy - GRU')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.ylim(0,1)
plt.legend(['train', 'val'], loc='best')
plt.show()

plt.plot(lstm.history['loss'])
plt.plot(lstm.history['val_loss'])
plt.title('model loss - GRU')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='best')
plt.show()

# %% [markdown]
# RNN Model

# %%
from keras.layers import SimpleRNN

# %%
# Simple RNN model
from keras.backend import clear_session
filepath = 'har_model_rnn.h5'

clear_session()
model = Sequential()

model.add(SimpleRNN(200,input_shape=(N_TIME_STEPS, N_FEATURES), return_sequences=True,kernel_initializer='orthogonal',
                             kernel_regularizer=l2(L2), recurrent_regularizer=l2(L2),
                             bias_regularizer=l2(L2),))


model.add(Flatten(name='Flatten'))
model.add(Dense(128, activation='relu', kernel_regularizer=l2(L2), bias_regularizer=l2(L2), name="Dense_3"))
model.add(Dropout(0.2))
model.add(Dense(N_CLASSES, activation='softmax', kernel_regularizer=l2(L2), bias_regularizer=l2(L2), name="Dense_4"))


model.summary()

checkpoint = ModelCheckpoint(filepath=filepath,
                             monitor='val_loss',
                             verbose=1,
                             save_best_only=True)
stop = EarlyStopping(monitor='val_loss', patience =5,
                      verbose=0, mode='auto', baseline=None, 
                      restore_best_weights=False)
reduce =  ReduceLROnPlateau(monitor='val_loss',
                    factor=0.5,
                    patience=2,
                    verbose=1)
callbacks = [checkpoint,stop]

model.compile(optimizer="adam",loss='categorical_crossentropy',metrics=['accuracy'])

BATCH_SIZE =64
N_EPOCHS = 300

lstm = model.fit(X_train, y_train,
          batch_size=BATCH_SIZE, shuffle=True,epochs=N_EPOCHS,callbacks=callbacks,
          validation_data=(X_test, y_test))
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn (SimpleRNN)      (None, 5, 200)            41200
#
#  Flatten (Flatten)           (None, 1000)              0
#
#  Dense_3 (Dense)             (None, 128)               128128
#
#  dropout (Dropout)           (None, 128)               0
#
#  Dense_4 (Dense)             (None, 4)                 516
#
# =================================================================
# Total params: 169,844
# Trainable params: 169,844
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/300
# 1884/1888 [============================>.] - ETA: 0s - loss: 0.1771 - accuracy: 0.9440
# Epoch 1: val_loss improved from inf to 0.06918, saving model to har_model_rnn.h5
# 1888/1888 [==============================] - 16s 8ms/step - loss: 0.1769 - accuracy: 0.9440 - val_loss: 0.0692 - val_accuracy: 0.9827
# Epoch 2/300
# 1887/1888 [============================>.] - ETA: 0s - loss: 0.0962 - accuracy: 0.9757
# Epoch 2: val_loss improved from 0.06918 to 0.03763, saving model to har_model_rnn.h5
# 1888/1888 [==============================] - 15s 8ms/step - loss: 0.0963 - accuracy: 0.9757 - val_loss: 0.0376 - val_accuracy: 0.9909
# Epoch 3/300
# 1886/1888 [============================>.] - ETA: 0s - loss: 0.0855 - accuracy: 0.9783
# Epoch 3: val_loss did not improve from 0.03763
# 1888/1888 [==============================] - 16s 9ms/step - loss: 0.0855 - accuracy: 0.9783 - val_loss: 0.0401 - val_accuracy: 0.9929
# Epoch 4/300
# 1883/1888 [============================>.] - ETA: 0s - loss: 0.0774 - accuracy: 0.9810
# Epoch 4: val_loss did not improve from 0.03763
# 1888/1888 [==============================] - 14s 8ms/step - loss: 0.0774 - accuracy: 0.9810 - val_loss: 0.0395 - val_accuracy: 0.9933
# Epoch 5/300
# 1887/1888 [============================>.] - ETA: 0s - loss: 0.0715 - accuracy: 0.9828
# Epoch 5: val_loss improved from 0.03763 to 0.03020, saving model to har_model_rnn.h5
# 1888/1888 [==============================] - 15s 8ms/step - loss: 0.0715 - accuracy: 0.9828 - val_loss: 0.0302 - val_accuracy: 0.9936
# Epoch 6/300
# 1884/1888 [============================>.] - ETA: 0s - loss: 0.0681 - accuracy: 0.9832
# Epoch 6: val_loss improved from 0.03020 to 0.02995, saving model to har_model_rnn.h5
# 1888/1888 [==============================] - 15s 8ms/step - loss: 0.0681 - accuracy: 0.9832 - val_loss: 0.0300 - val_accuracy: 0.9930
# Epoch 7/300
# 1887/1888 [============================>.] - ETA: 0s - loss: 0.0622 - accuracy: 0.9851
# Epoch 7: val_loss improved from 0.02995 to 0.02443, saving model to har_model_rnn.h5
# 1888/1888 [==============================] - 15s 8ms/step - loss: 0.0622 - accuracy: 0.9851 - val_loss: 0.0244 - val_accuracy: 0.9941
# Epoch 8/300
# 1883/1888 [============================>.] - ETA: 0s - loss: 0.0563 - accuracy: 0.9864
# Epoch 8: val_loss did not improve from 0.02443
# 1888/1888 [==============================] - 14s 7ms/step - loss: 0.0563 - accuracy: 0.9864 - val_loss: 0.0383 - val_accuracy: 0.9901
# Epoch 9/300
# 1885/1888 [============================>.] - ETA: 0s - loss: 0.0538 - accuracy: 0.9871
# Epoch 9: val_loss did not improve from 0.02443
# 1888/1888 [==============================] - 14s 8ms/step - loss: 0.0538 - accuracy: 0.9871 - val_loss: 0.0314 - val_accuracy: 0.9922
# Epoch 10/300
# 1887/1888 [============================>.] - ETA: 0s - loss: 0.0506 - accuracy: 0.9883
# Epoch 10: val_loss improved from 0.02443 to 0.02357, saving model to har_model_rnn.h5
# 1888/1888 [==============================] - 15s 8ms/step - loss: 0.0506 - accuracy: 0.9883 - val_loss: 0.0236 - val_accuracy: 0.9943
# Epoch 11/300
# 1884/1888 [============================>.] - ETA: 0s - loss: 0.0463 - accuracy: 0.9893
# Epoch 11: val_loss did not improve from 0.02357
# 1888/1888 [==============================] - 15s 8ms/step - loss: 0.0463 - accuracy: 0.9893 - val_loss: 0.0402 - val_accuracy: 0.9918
# Epoch 12/300
# 1884/1888 [============================>.] - ETA: 0s - loss: 0.0451 - accuracy: 0.9898
# Epoch 12: val_loss did not improve from 0.02357
# 1888/1888 [==============================] - 16s 8ms/step - loss: 0.0452 - accuracy: 0.9898 - val_loss: 0.0327 - val_accuracy: 0.9921
# Epoch 13/300
# 1882/1888 [============================>.] - ETA: 0s - loss: 0.0401 - accuracy: 0.9911
# Epoch 13: val_loss improved from 0.02357 to 0.01696, saving model to har_model_rnn.h5
# 1888/1888 [==============================] - 14s 8ms/step - loss: 0.0401 - accuracy: 0.9911 - val_loss: 0.0170 - val_accuracy: 0.9976
# Epoch 14/300
# 1881/1888 [============================>.] - ETA: 0s - loss: 0.0382 - accuracy: 0.9915
# Epoch 14: val_loss did not improve from 0.01696
# 1888/1888 [==============================] - 14s 8ms/step - loss: 0.0381 - accuracy: 0.9915 - val_loss: 0.0218 - val_accuracy: 0.9960
# Epoch 15/300
# 1884/1888 [============================>.] - ETA: 0s - loss: 0.0386 - accuracy: 0.9919
# Epoch 15: val_loss did not improve from 0.01696
# 1888/1888 [==============================] - 19s 10ms/step - loss: 0.0386 - accuracy: 0.9919 - val_loss: 0.0207 - val_accuracy: 0.9962
# Epoch 16/300
# 1888/1888 [==============================] - ETA: 0s - loss: 0.0334 - accuracy: 0.9935
# Epoch 16: val_loss did not improve from 0.01696
# 1888/1888 [==============================] - 14s 8ms/step - loss: 0.0334 - accuracy: 0.9935 - val_loss: 0.0173 - val_accuracy: 0.9989
# Epoch 17/300
# 1887/1888 [============================>.] - ETA: 0s - loss: 0.0332 - accuracy: 0.9934
# Epoch 17: val_loss did not improve from 0.01696
# 1888/1888 [==============================] - 16s 8ms/step - loss: 0.0332 - accuracy: 0.9934 - val_loss: 0.0196 - val_accuracy: 0.9973
# Epoch 18/300
# 1883/1888 [============================>.] - ETA: 0s - loss: 0.0318 - accuracy: 0.9936
# Epoch 18: val_loss did not improve from 0.01696
# 1888/1888 [==============================] - 14s 7ms/step - loss: 0.0318 - accuracy: 0.9936 - val_loss: 0.0175 - val_accuracy: 0.9979

# %%
# RNN model to predict

y_pred_ohe = model.predict(X_test)
y_pred_labels = np.argmax(y_pred_ohe, axis=1)
y_true_labels = np.argmax(y_test, axis=1)
confusion_matrix = metrics.confusion_matrix(y_true=y_true_labels, y_pred=y_pred_labels)
print(y_true_labels)
LABELS = ['seated', 'stand','walk','iwuphill']

plt.figure(figsize=(8, 6))
sns.set(style='whitegrid', palette='muted', font_scale=1.5)
sns.heatmap(confusion_matrix, xticklabels=LABELS, yticklabels=LABELS, annot=True, fmt="d");
plt.title("Confusion matrix - SimpleRNN")
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.show();
# Out:
# 944/944 [==============================] - 2s 2ms/step
# [1 1 1 ... 0 0 0]

# %%
predIdxs = model.predict(X_test, batch_size=BATCH_SIZE)
predIdxs = np.argmax(predIdxs, axis=1)

# show a classification report
print(classification_report(y_test.argmax(axis=1), predIdxs,
	target_names=['seated', 'stand','walk','iwuphill']))
# Out:
# 472/472 [==============================] - 1s 2ms/step
#               precision    recall  f1-score   support
#
#       seated       1.00      1.00      1.00      2321
#        stand       1.00      1.00      1.00     10803
#         walk       1.00      1.00      1.00      9032
#     iwuphill       1.00      1.00      1.00      8048
#
#     accuracy                           1.00     30204
#    macro avg       1.00      1.00      1.00     30204
# weighted avg       1.00      1.00      1.00     30204

# %%
plt.plot(lstm.history['accuracy'])
plt.plot(lstm.history['val_accuracy'])
plt.title('model accuracy - SimpleRNN')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.ylim(0,1)
plt.legend(['train', 'val'], loc='best')
plt.show()

plt.plot(lstm.history['loss'])
plt.plot(lstm.history['val_loss'])
plt.title('model loss - SimpleRNN')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='best')
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import plotly.express as px
import plotly.graph_objects as go

import tsaug
from tsaug import TimeWarp, Crop, Quantize, Drift, Reverse

# %%
df= pd.read_csv('base_one_col_sensors/seated/seated10.csv')
#df.head()

# %%
Y_Q_I_1 = df['Q_I_1'].tolist()
Y_Q_I_1 = np.array(Y_Q_I_1)
Y_Q_I_1[:3]

Y_Q_J_1 = df['Q_J_1'].tolist()
Y_Q_J_1 = np.array(Y_Q_J_1)
Y_Q_J_1[:3]

Y_Q_K_1 = df['Q_K_1'].tolist()
Y_Q_K_1 = np.array(Y_Q_K_1)
Y_Q_K_1[:3]

Y_Q_R_1 = df['Q_R_1'].tolist()
Y_Q_R_1 = np.array(Y_Q_R_1)
Y_Q_R_1[:3]
#######################################################################

Y_Q_I_2 = df['Q_I_2'].tolist()
Y_Q_I_2 = np.array(Y_Q_I_2)
Y_Q_I_2[:3]

Y_Q_J_2 = df['Q_J_2'].tolist()
Y_Q_J_2 = np.array(Y_Q_J_2)
Y_Q_J_2[:3]

Y_Q_K_2 = df['Q_K_2'].tolist()
Y_Q_K_2 = np.array(Y_Q_K_2)
Y_Q_K_2[:3]

Y_Q_R_2 = df['Q_R_2'].tolist()
Y_Q_R_2 = np.array(Y_Q_R_2)
Y_Q_R_2[:3]
########################################################################


Y_Q_I_3 = df['Q_I_3'].tolist()
Y_Q_I_3 = np.array(Y_Q_I_3)
Y_Q_I_3[:3]

Y_Q_J_3 = df['Q_J_3'].tolist()
Y_Q_J_3 = np.array(Y_Q_J_3)
Y_Q_J_3[:3]

Y_Q_K_3 = df['Q_K_3'].tolist()
Y_Q_K_3 = np.array(Y_Q_K_3)
Y_Q_K_3[:3]

Y_Q_R_3 = df['Q_R_3'].tolist()
Y_Q_R_3 = np.array(Y_Q_R_3)
Y_Q_R_3[:3]
########################################################################


Y_Q_I_4 = df['Q_I_4'].tolist()
Y_Q_I_4 = np.array(Y_Q_I_4)
Y_Q_I_4[:3]

Y_Q_J_4 = df['Q_J_4'].tolist()
Y_Q_J_4 = np.array(Y_Q_J_4)
Y_Q_J_4[:3]

Y_Q_K_4 = df['Q_K_4'].tolist()
Y_Q_K_4 = np.array(Y_Q_K_4)
Y_Q_K_4[:3]

Y_Q_R_4 = df['Q_R_4'].tolist()
Y_Q_R_4 = np.array(Y_Q_R_4)
Y_Q_R_4[:3]
# Out:
# array([0.68, 0.68, 0.68])

# %%
X_I_1 = np.arange(len(df['Q_I_1']))
X_J_1 = np.arange(len(df['Q_J_1']))
X_K_1 = np.arange(len(df['Q_K_1']))
X_R_1 = np.arange(len(df['Q_R_1']))

X_I_2 = np.arange(len(df['Q_I_2']))
X_J_2 = np.arange(len(df['Q_J_2']))
X_K_2 = np.arange(len(df['Q_K_2']))
X_R_2 = np.arange(len(df['Q_R_2']))

X_I_3 = np.arange(len(df['Q_I_3']))
X_J_3 = np.arange(len(df['Q_J_3']))
X_K_3 = np.arange(len(df['Q_K_3']))
X_R_3 = np.arange(len(df['Q_R_3']))

X_I_4 = np.arange(len(df['Q_I_4']))
X_J_4 = np.arange(len(df['Q_J_4']))
X_K_4 = np.arange(len(df['Q_K_4']))
X_R_4 = np.arange(len(df['Q_R_4']))

# %%
##### SENSOR 1
#Noise
Y_I_SENSOR1_aug1, X_I_SENSOR1_aug1 = tsaug.AddNoise(scale=0.1).augment(Y_Q_I_1, X_I_1)
Y_I_SENSOR1_aug2, X_I_SENSOR1_aug2 = tsaug.AddNoise(scale=0.05).augment(Y_Q_I_1, X_I_1)

# Convolve

Y_I_SENSOR1_aug3, X_I_SENSOR1_aug3 = tsaug.Convolve(window="flat", size=10).augment(Y_Q_I_1, X_I_1)
Y_I_SENSOR1_aug4, X_I_SENSOR1_aug4 = tsaug.Convolve(window="flat", size=5).augment(Y_Q_I_1, X_I_1)

#Drift
Y_I_SENSOR1_aug5, X_I_SENSOR1_aug5 = tsaug.Drift(max_drift=0.3, n_drift_points=5).augment(Y_Q_I_1, X_I_1)
Y_I_SENSOR1_aug6, X_I_SENSOR1_aug6 = tsaug.Drift(max_drift=0.5, n_drift_points=5).augment(Y_Q_I_1, X_I_1)

Y_I_SENSOR1_aug7, X_I_SENSOR1_aug7 = tsaug.Drift(max_drift=0.3, n_drift_points=5).augment(Y_Q_I_1, X_I_1)
Y_I_SENSOR1_aug8, X_I_SENSOR1_aug8 = tsaug.Drift(max_drift=0.3, n_drift_points=3).augment(Y_Q_I_1, X_I_1)

#Quantize
Y_I_SENSOR1_aug9, X_I_SENSOR1_aug9 = tsaug.Quantize(n_levels=10).augment(Y_Q_I_1, X_I_1)
Y_I_SENSOR1_aug10, X_I_SENSOR1_aug10 = tsaug.Quantize(n_levels=20).augment(Y_Q_I_1, X_I_1)

#-------------------------------------------J----------------------------------------------------------

#Noise
Y_J_SENSOR1_aug1, X_J_SENSOR1_aug1 = tsaug.AddNoise(scale=0.1).augment(Y_Q_J_1, X_J_1)
Y_J_SENSOR1_aug2, X_J_SENSOR1_aug2 = tsaug.AddNoise(scale=0.05).augment(Y_Q_J_1, X_J_1)

# Convolve

Y_J_SENSOR1_aug3, X_J_SENSOR1_aug3 = tsaug.Convolve(window="flat", size=10).augment(Y_Q_J_1, X_J_1)
Y_J_SENSOR1_aug4, X_J_SENSOR1_aug4 = tsaug.Convolve(window="flat", size=5).augment(Y_Q_J_1, X_J_1)

#Drift
Y_J_SENSOR1_aug5, X_J_SENSOR1_aug5 = tsaug.Drift(max_drift=0.3, n_drift_points=5).augment(Y_Q_J_1, X_J_1)
Y_J_SENSOR1_aug6, X_J_SENSOR1_aug6 = tsaug.Drift(max_drift=0.5, n_drift_points=5).augment(Y_Q_J_1, X_J_1)

Y_J_SENSOR1_aug7, X_J_SENSOR1_aug7 = tsaug.Drift(max_drift=0.3, n_drift_points=5).augment(Y_Q_J_1, X_J_1)
Y_J_SENSOR1_aug8, X_J_SENSOR1_aug8 = tsaug.Drift(max_drift=0.3, n_drift_points=3).augment(Y_Q_J_1, X_J_1)

##Quantize
Y_J_SENSOR1_aug9, X_J_SENSOR1_aug9 = tsaug.Quantize(n_levels=10).augment(Y_Q_J_1, X_J_1)
Y_J_SENSOR1_aug10, X_J_SENSOR1_aug10 = tsaug.Quantize(n_levels=20).augment(Y_Q_J_1, X_J_1)


#-------------------------------------------K----------------------------------------------------------


#Noise
Y_K_SENSOR1_aug1, X_K_SENSOR1_aug1 = tsaug.AddNoise(scale=0.1).augment(Y_Q_K_1, X_K_1)
Y_K_SENSOR1_aug2, X_K_SENSOR1_aug2 = tsaug.AddNoise(scale=0.05).augment(Y_Q_K_1, X_K_1)

#Convolve

Y_K_SENSOR1_aug3, X_K_SENSOR1_aug3 = tsaug.Convolve(window="flat", size=10).augment(Y_Q_K_1, X_K_1)
Y_K_SENSOR1_aug4, X_K_SENSOR1_aug4 = tsaug.Convolve(window="flat", size=5).augment(Y_Q_K_1, X_K_1)

#Drift
Y_K_SENSOR1_aug5, X_K_SENSOR1_aug5 = tsaug.Drift(max_drift=0.3, n_drift_points=5).augment(Y_Q_K_1, X_K_1)
Y_K_SENSOR1_aug6, X_K_SENSOR1_aug6 = tsaug.Drift(max_drift=0.5, n_drift_points=5).augment(Y_Q_K_1, X_K_1)

Y_K_SENSOR1_aug7, X_K_SENSOR1_aug7 = tsaug.Drift(max_drift=0.3, n_drift_points=5).augment(Y_Q_K_1, X_K_1)
Y_K_SENSOR1_aug8, X_K_SENSOR1_aug8 = tsaug.Drift(max_drift=0.3, n_drift_points=3).augment(Y_Q_K_1, X_K_1)

#Quantize
Y_K_SENSOR1_aug9, X_K_SENSOR1_aug9 = tsaug.Quantize(n_levels=10).augment(Y_Q_K_1, X_K_1)
Y_K_SENSOR1_aug10, X_K_SENSOR1_aug10 = tsaug.Quantize(n_levels=20).augment(Y_Q_K_1, X_K_1)

#-----------------------------------R----------------------------------

#Noise
Y_R_SENSOR1_aug1, X_R_SENSOR1_aug1 = tsaug.AddNoise(scale=0.1).augment(Y_Q_R_1, X_R_1)
Y_R_SENSOR1_aug2, X_R_SENSOR1_aug2 = tsaug.AddNoise(scale=0.05).augment(Y_Q_R_1, X_R_1)

# Convolve

Y_R_SENSOR1_aug3, X_R_SENSOR1_aug3 = tsaug.Convolve(window="flat", size=10).augment(Y_Q_R_1, X_R_1)
Y_R_SENSOR1_aug4, X_R_SENSOR1_aug4 = tsaug.Convolve(window="flat", size=5).augment(Y_Q_R_1, X_R_1)

#Drift
Y_R_SENSOR1_aug5, X_R_SENSOR1_aug5 = tsaug.Drift(max_drift=0.3, n_drift_points=5).augment(Y_Q_R_1, X_R_1)
Y_R_SENSOR1_aug6, X_R_SENSOR1_aug6 = tsaug.Drift(max_drift=0.5, n_drift_points=5).augment(Y_Q_R_1, X_R_1)

Y_R_SENSOR1_aug7, X_R_SENSOR1_aug7 = tsaug.Drift(max_drift=0.3, n_drift_points=5).augment(Y_Q_R_1, X_R_1)
Y_R_SENSOR1_aug8, X_R_SENSOR1_aug8 = tsaug.Drift(max_drift=0.3, n_drift_points=3).augment(Y_Q_R_1, X_R_1)

#Quantize
Y_R_SENSOR1_aug9, X_R_SENSOR1_aug9 = tsaug.Quantize(n_levels=10).augment(Y_Q_R_1, X_R_1)
Y_R_SENSOR1_aug10, X_R_SENSOR1_aug10 = tsaug.Quantize(n_levels=20).augment(Y_Q_R_1, X_R_1)

# %%
##### SENSOR 2 

#Noise
Y_I_SENSOR2_aug1, X_I_aug1 = tsaug.AddNoise(scale=0.1).augment(Y_Q_I_2, X_I_2)
Y_I_SENSOR2_aug2, X_I_aug2 = tsaug.AddNoise(scale=0.05).augment(Y_Q_I_2, X_I_2)

#Convolve

Y_I_SENSOR2_aug3, X_I_aug3 = tsaug.Convolve(window="flat", size=10).augment(Y_Q_I_2, X_I_2)
Y_I_SENSOR2_aug4, X_I_aug4 = tsaug.Convolve(window="flat", size=5).augment(Y_Q_I_2, X_I_2)

#Drift
Y_I_SENSOR2_aug5, X_I_aug5 = tsaug.Drift(max_drift=0.3, n_drift_points=5).augment(Y_Q_I_2, X_I_2)
Y_I_SENSOR2_aug6, X_I_aug6 = tsaug.Drift(max_drift=0.5, n_drift_points=5).augment(Y_Q_I_2, X_I_2)

Y_I_SENSOR2_aug7, X_I_aug7 = tsaug.Drift(max_drift=0.3, n_drift_points=5).augment(Y_Q_I_2, X_I_2)
Y_I_SENSOR2_aug8, X_I_aug8 = tsaug.Drift(max_drift=0.3, n_drift_points=3).augment(Y_Q_I_2, X_I_2)

#Quantize
Y_I_SENSOR2_aug9, X_I_aug9 = tsaug.Quantize(n_levels=10).augment(Y_Q_I_2, X_I_2)
Y_I_SENSOR2_aug10, X_I_aug10 = tsaug.Quantize(n_levels=20).augment(Y_Q_I_2, X_I_2)

#-------------------------------------------J----------------------------------------------------------

#Noise
Y_J_SENSOR2_aug1, X_J_SENSOR2_aug1 = tsaug.AddNoise(scale=0.1).augment(Y_Q_J_2, X_J_2)
Y_J_SENSOR2_aug2, X_J_SENSOR2_aug2 = tsaug.AddNoise(scale=0.05).augment(Y_Q_J_2, X_J_2)

#Convolve

Y_J_SENSOR2_aug3, X_J_SENSOR2_aug3 = tsaug.Convolve(window="flat", size=10).augment(Y_Q_J_2, X_J_2)
Y_J_SENSOR2_aug4, X_J_SENSOR2_aug4 = tsaug.Convolve(window="flat", size=5).augment(Y_Q_J_2, X_J_2)

#Drift
Y_J_SENSOR2_aug5, X_J_SENSOR2_aug5 = tsaug.Drift(max_drift=0.3, n_drift_points=5).augment(Y_Q_J_2, X_J_2)
Y_J_SENSOR2_aug6, X_J_SENSOR2_aug6 = tsaug.Drift(max_drift=0.5, n_drift_points=5).augment(Y_Q_J_2, X_J_2)

Y_J_SENSOR2_aug7, X_J_SENSOR2_aug7 = tsaug.Drift(max_drift=0.3, n_drift_points=5).augment(Y_Q_J_2, X_J_2)
Y_J_SENSOR2_aug8, X_J_SENSOR2_aug8 = tsaug.Drift(max_drift=0.3, n_drift_points=3).augment(Y_Q_J_2, X_J_2)

#Quantize
Y_J_SENSOR2_aug9, X_J_SENSOR2_aug9 = tsaug.Quantize(n_levels=10).augment(Y_Q_J_2, X_J_2)
Y_J_SENSOR2_aug10, X_J_SENSOR2_aug10 = tsaug.Quantize(n_levels=20).augment(Y_Q_J_2, X_J_2)


#-------------------------------------------K----------------------------------------------------------

#Noise
Y_K_SENSOR2_aug1, X_K_SENSOR2_aug1 = tsaug.AddNoise(scale=0.1).augment(Y_Q_K_2, X_K_2)
Y_K_SENSOR2_aug2, X_K_SENSOR2_aug2 = tsaug.AddNoise(scale=0.05).augment(Y_Q_K_2, X_K_2)

# Convolve

Y_K_SENSOR2_aug3, X_K_SENSOR2_aug3 = tsaug.Convolve(window="flat", size=10).augment(Y_Q_K_2, X_K_2)
Y_K_SENSOR2_aug4, X_K_SENSOR2_aug4 = tsaug.Convolve(window="flat", size=5).augment(Y_Q_K_2, X_K_2)

#Drift
Y_K_SENSOR2_aug5, X_K_SENSOR2_aug5 = tsaug.Drift(max_drift=0.3, n_drift_points=5).augment(Y_Q_K_2, X_K_2)
Y_K_SENSOR2_aug6, X_K_SENSOR2_aug6 = tsaug.Drift(max_drift=0.5, n_drift_points=5).augment(Y_Q_K_2, X_K_2)

Y_K_SENSOR2_aug7, X_K_SENSOR2_aug7 = tsaug.Drift(max_drift=0.3, n_drift_points=5).augment(Y_Q_K_2, X_K_2)
Y_K_SENSOR2_aug8, X_K_SENSOR2_aug8 = tsaug.Drift(max_drift=0.3, n_drift_points=3).augment(Y_Q_K_2, X_K_2)

#Quantize
Y_K_SENSOR2_aug9, X_K_SENSOR2_aug9 = tsaug.Quantize(n_levels=10).augment(Y_Q_K_1, X_K_2)
Y_K_SENSOR2_aug10, X_K_SENSOR2_aug10 = tsaug.Quantize(n_levels=20).augment(Y_Q_K_1, X_K_2)

#-----------------------------------R----------------------------------

#Noise
Y_R_SENSOR2_aug1, X_R_SENSOR2_aug1 = tsaug.AddNoise(scale=0.1).augment(Y_Q_R_2, X_R_2)
Y_R_SENSOR2_aug2, X_R_SENSOR2_aug2 = tsaug.AddNoise(scale=0.05).augment(Y_Q_R_2, X_R_2)

#Convolve

Y_R_SENSOR2_aug3, X_R_SENSOR2_aug3 = tsaug.Convolve(window="flat", size=10).augment(Y_Q_R_2, X_R_2)
Y_R_SENSOR2_aug4, X_R_SENSOR2_aug4 = tsaug.Convolve(window="flat", size=5).augment(Y_Q_R_2, X_R_2)

#Drift
Y_R_SENSOR2_aug5, X_R_SENSOR2_aug5 = tsaug.Drift(max_drift=0.3, n_drift_points=5).augment(Y_Q_R_2, X_R_2)
Y_R_SENSOR2_aug6, X_R_SENSOR2_aug6 = tsaug.Drift(max_drift=0.5, n_drift_points=5).augment(Y_Q_R_2, X_R_2)

Y_R_SENSOR2_aug7, X_R_SENSOR2_aug7 = tsaug.Drift(max_drift=0.3, n_drift_points=5).augment(Y_Q_R_2, X_R_2)
Y_R_SENSOR2_aug8, X_R_SENSOR2_aug8 = tsaug.Drift(max_drift=0.3, n_drift_points=3).augment(Y_Q_R_2, X_R_2)

#Quantize
Y_R_SENSOR2_aug9, X_R_SENSOR2_aug9 = tsaug.Quantize(n_levels=10).augment(Y_Q_R_2, X_R_2)
Y_R_SENSOR2_aug10, X_R_SENSOR2_aug10 = tsaug.Quantize(n_levels=20).augment(Y_Q_R_1, X_R_2)

# %%
##### SENSOR 3 

#Noise
Y_I_SENSOR3_aug1, X_I_aug1 = tsaug.AddNoise(scale=0.1).augment(Y_Q_I_3, X_I_3)
Y_I_SENSOR3_aug2, X_I_aug2 = tsaug.AddNoise(scale=0.05).augment(Y_Q_I_3, X_I_3)

#Convolve

Y_I_SENSOR3_aug3, X_I_aug3 = tsaug.Convolve(window="flat", size=10).augment(Y_Q_I_3, X_I_3)
Y_I_SENSOR3_aug4, X_I_aug4 = tsaug.Convolve(window="flat", size=5).augment(Y_Q_I_3, X_I_3)

#Drift
Y_I_SENSOR3_aug5, X_I_aug5 = tsaug.Drift(max_drift=0.3, n_drift_points=5).augment(Y_Q_I_3, X_I_3)
Y_I_SENSOR3_aug6, X_I_aug6 = tsaug.Drift(max_drift=0.5, n_drift_points=5).augment(Y_Q_I_3, X_I_3)

Y_I_SENSOR3_aug7, X_I_aug7 = tsaug.Drift(max_drift=0.3, n_drift_points=5).augment(Y_Q_I_3, X_I_3)
Y_I_SENSOR3_aug8, X_I_aug8 = tsaug.Drift(max_drift=0.3, n_drift_points=3).augment(Y_Q_I_3, X_I_3)

#Quantize
Y_I_SENSOR3_aug9, X_I_aug9 = tsaug.Quantize(n_levels=10).augment(Y_Q_I_3, X_I_3)
Y_I_SENSOR3_aug10, X_I_aug10 = tsaug.Quantize(n_levels=20).augment(Y_Q_I_3, X_I_3)

#-------------------------------------------J----------------------------------------------------------

#Noise
Y_J_SENSOR3_aug1, X_J_SENSOR3_aug1 = tsaug.AddNoise(scale=0.1).augment(Y_Q_J_3, X_J_3)
Y_J_SENSOR3_aug2, X_J_SENSOR3_aug2 = tsaug.AddNoise(scale=0.05).augment(Y_Q_J_3, X_J_3)

#Convolve

Y_J_SENSOR3_aug3, X_J_SENSOR3_aug3 = tsaug.Convolve(window="flat", size=10).augment(Y_Q_J_3, X_J_3)
Y_J_SENSOR3_aug4, X_J_SENSOR3_aug4 = tsaug.Convolve(window="flat", size=5).augment(Y_Q_J_3, X_J_3)

#Drift
Y_J_SENSOR3_aug5, X_J_SENSOR3_aug5 = tsaug.Drift(max_drift=0.3, n_drift_points=5).augment(Y_Q_J_3, X_J_3)
Y_J_SENSOR3_aug6, X_J_SENSOR3_aug6 = tsaug.Drift(max_drift=0.5, n_drift_points=5).augment(Y_Q_J_3, X_J_3)

Y_J_SENSOR3_aug7, X_J_SENSOR3_aug7 = tsaug.Drift(max_drift=0.3, n_drift_points=5).augment(Y_Q_J_3, X_J_3)
Y_J_SENSOR3_aug8, X_J_SENSOR3_aug8 = tsaug.Drift(max_drift=0.3, n_drift_points=3).augment(Y_Q_J_3, X_J_3)

#Quantize
Y_J_SENSOR3_aug9, X_J_SENSOR3_aug9 = tsaug.Quantize(n_levels=10).augment(Y_Q_J_3, X_J_3)
Y_J_SENSOR3_aug10, X_J_SENSOR3_aug10 = tsaug.Quantize(n_levels=20).augment(Y_Q_J_3, X_J_3)


#-------------------------------------------K----------------------------------------------------------

#Noise
Y_K_SENSOR3_aug1, X_K_SENSOR3_aug1 = tsaug.AddNoise(scale=0.1).augment(Y_Q_K_3, X_K_3)
Y_K_SENSOR3_aug2, X_K_SENSOR3_aug2 = tsaug.AddNoise(scale=0.05).augment(Y_Q_K_3, X_K_3)

# Convolve

Y_K_SENSOR3_aug3, X_K_SENSOR3_aug3 = tsaug.Convolve(window="flat", size=10).augment(Y_Q_K_3, X_K_3)
Y_K_SENSOR3_aug4, X_K_SENSOR3_aug4 = tsaug.Convolve(window="flat", size=5).augment(Y_Q_K_3, X_K_3)

#Drift
Y_K_SENSOR3_aug5, X_K_SENSOR3_aug5 = tsaug.Drift(max_drift=0.3, n_drift_points=5).augment(Y_Q_K_3, X_K_3)
Y_K_SENSOR3_aug6, X_K_SENSOR3_aug6 = tsaug.Drift(max_drift=0.5, n_drift_points=5).augment(Y_Q_K_3, X_K_3)

Y_K_SENSOR3_aug7, X_K_SENSOR3_aug7 = tsaug.Drift(max_drift=0.3, n_drift_points=5).augment(Y_Q_K_3, X_K_3)
Y_K_SENSOR3_aug8, X_K_SENSOR3_aug8 = tsaug.Drift(max_drift=0.3, n_drift_points=3).augment(Y_Q_K_3, X_K_3)

#Quantize
Y_K_SENSOR3_aug9, X_K_SENSOR3_aug9 = tsaug.Quantize(n_levels=10).augment(Y_Q_K_3, X_K_3)
Y_K_SENSOR3_aug10, X_K_SENSOR3_aug10 = tsaug.Quantize(n_levels=20).augment(Y_Q_K_3, X_K_3)

#-----------------------------------R----------------------------------

#Noise
Y_R_SENSOR3_aug1, X_R_SENSOR3_aug1 = tsaug.AddNoise(scale=0.1).augment(Y_Q_R_3, X_R_3)
Y_R_SENSOR3_aug2, X_R_SENSOR3_aug2 = tsaug.AddNoise(scale=0.05).augment(Y_Q_R_3, X_R_3)

#Convolve

Y_R_SENSOR3_aug3, X_R_SENSOR3_aug3 = tsaug.Convolve(window="flat", size=10).augment(Y_Q_R_3, X_R_3)
Y_R_SENSOR3_aug4, X_R_SENSOR3_aug4 = tsaug.Convolve(window="flat", size=5).augment(Y_Q_R_3, X_R_3)

#Drift
Y_R_SENSOR3_aug5, X_R_SENSOR3_aug5 = tsaug.Drift(max_drift=0.3, n_drift_points=5).augment(Y_Q_R_3, X_R_3)
Y_R_SENSOR3_aug6, X_R_SENSOR3_aug6 = tsaug.Drift(max_drift=0.5, n_drift_points=5).augment(Y_Q_R_3, X_R_3)

Y_R_SENSOR3_aug7, X_R_SENSOR3_aug7 = tsaug.Drift(max_drift=0.3, n_drift_points=5).augment(Y_Q_R_3, X_R_3)
Y_R_SENSOR3_aug8, X_R_SENSOR3_aug8 = tsaug.Drift(max_drift=0.3, n_drift_points=3).augment(Y_Q_R_3, X_R_3)

#Quantize
Y_R_SENSOR3_aug9, X_R_SENSOR3_aug9 = tsaug.Quantize(n_levels=10).augment(Y_Q_R_3, X_R_3)
Y_R_SENSOR3_aug10, X_R_SENSOR3_aug10 = tsaug.Quantize(n_levels=20).augment(Y_Q_R_3, X_R_3)

# %%
##### SENSOR 4 

#Noise
Y_I_SENSOR4_aug1, X_I_aug1 = tsaug.AddNoise(scale=0.1).augment(Y_Q_I_4, X_I_4)
Y_I_SENSOR4_aug2, X_I_aug2 = tsaug.AddNoise(scale=0.05).augment(Y_Q_I_4, X_I_4)

#Convolve

Y_I_SENSOR4_aug3, X_I_aug3 = tsaug.Convolve(window="flat", size=10).augment(Y_Q_I_4, X_I_4)
Y_I_SENSOR4_aug4, X_I_aug4 = tsaug.Convolve(window="flat", size=5).augment(Y_Q_I_4, X_I_4)

#Drift
Y_I_SENSOR4_aug5, X_I_aug5 = tsaug.Drift(max_drift=0.3, n_drift_points=5).augment(Y_Q_I_4, X_I_4)
Y_I_SENSOR4_aug6, X_I_aug6 = tsaug.Drift(max_drift=0.5, n_drift_points=5).augment(Y_Q_I_4, X_I_4)

Y_I_SENSOR4_aug7, X_I_aug7 = tsaug.Drift(max_drift=0.3, n_drift_points=5).augment(Y_Q_I_4, X_I_4)
Y_I_SENSOR4_aug8, X_I_aug8 = tsaug.Drift(max_drift=0.3, n_drift_points=3).augment(Y_Q_I_4, X_I_4)

#Quantize
Y_I_SENSOR4_aug9, X_I_aug9 = tsaug.Quantize(n_levels=10).augment(Y_Q_I_4, X_I_4)
Y_I_SENSOR4_aug10, X_I_aug10 = tsaug.Quantize(n_levels=20).augment(Y_Q_I_4, X_I_4)

#-------------------------------------------J----------------------------------------------------------

#Noise
Y_J_SENSOR4_aug1, X_J_SENSOR4_aug1 = tsaug.AddNoise(scale=0.1).augment(Y_Q_J_4, X_J_4)
Y_J_SENSOR4_aug2, X_J_SENSOR4_aug2 = tsaug.AddNoise(scale=0.05).augment(Y_Q_J_4, X_J_4)

#Convolve

Y_J_SENSOR4_aug3, X_J_SENSOR4_aug3 = tsaug.Convolve(window="flat", size=10).augment(Y_Q_J_4, X_J_4)
Y_J_SENSOR4_aug4, X_J_SENSOR4_aug4 = tsaug.Convolve(window="flat", size=5).augment(Y_Q_J_4, X_J_4)

#Drift
Y_J_SENSOR4_aug5, X_J_SENSOR4_aug5 = tsaug.Drift(max_drift=0.3, n_drift_points=5).augment(Y_Q_J_4, X_J_4)
Y_J_SENSOR4_aug6, X_J_SENSOR4_aug6 = tsaug.Drift(max_drift=0.5, n_drift_points=5).augment(Y_Q_J_4, X_J_4)

Y_J_SENSOR4_aug7, X_J_SENSOR4_aug7 = tsaug.Drift(max_drift=0.3, n_drift_points=5).augment(Y_Q_J_4, X_J_4)
Y_J_SENSOR4_aug8, X_J_SENSOR4_aug8 = tsaug.Drift(max_drift=0.3, n_drift_points=3).augment(Y_Q_J_4, X_J_4)

#Quantize
Y_J_SENSOR4_aug9, X_J_SENSOR4_aug9 = tsaug.Quantize(n_levels=10).augment(Y_Q_J_4, X_J_4)
Y_J_SENSOR4_aug10, X_J_SENSOR4_aug10 = tsaug.Quantize(n_levels=20).augment(Y_Q_J_4, X_J_4)


#-------------------------------------------K----------------------------------------------------------

#Noise
Y_K_SENSOR4_aug1, X_K_SENSOR4_aug1 = tsaug.AddNoise(scale=0.1).augment(Y_Q_K_4, X_K_4)
Y_K_SENSOR4_aug2, X_K_SENSOR4_aug2 = tsaug.AddNoise(scale=0.05).augment(Y_Q_K_4, X_K_4)

# Convolve

Y_K_SENSOR4_aug3, X_K_SENSOR4_aug3 = tsaug.Convolve(window="flat", size=10).augment(Y_Q_K_4, X_K_4)
Y_K_SENSOR4_aug4, X_K_SENSOR4_aug4 = tsaug.Convolve(window="flat", size=5).augment(Y_Q_K_4, X_K_4)

#Drift
Y_K_SENSOR4_aug5, X_K_SENSOR4_aug5 = tsaug.Drift(max_drift=0.3, n_drift_points=5).augment(Y_Q_K_4, X_K_4)
Y_K_SENSOR4_aug6, X_K_SENSOR4_aug6 = tsaug.Drift(max_drift=0.5, n_drift_points=5).augment(Y_Q_K_4, X_K_4)

Y_K_SENSOR4_aug7, X_K_SENSOR4_aug7 = tsaug.Drift(max_drift=0.3, n_drift_points=5).augment(Y_Q_K_4, X_K_4)
Y_K_SENSOR4_aug8, X_K_SENSOR4_aug8 = tsaug.Drift(max_drift=0.3, n_drift_points=3).augment(Y_Q_K_4, X_K_4)

#Quantize
Y_K_SENSOR4_aug9, X_K_SENSOR4_aug9 = tsaug.Quantize(n_levels=10).augment(Y_Q_K_4, X_K_4)
Y_K_SENSOR4_aug10, X_K_SENSOR4_aug10 = tsaug.Quantize(n_levels=20).augment(Y_Q_K_4, X_K_4)

#-----------------------------------R----------------------------------

#Noise
Y_R_SENSOR4_aug1, X_R_SENSOR4_aug1 = tsaug.AddNoise(scale=0.1).augment(Y_Q_R_4, X_R_4)
Y_R_SENSOR4_aug2, X_R_SENSOR4_aug2 = tsaug.AddNoise(scale=0.05).augment(Y_Q_R_4, X_R_4)

#Convolve

Y_R_SENSOR4_aug3, X_R_SENSOR4_aug3 = tsaug.Convolve(window="flat", size=10).augment(Y_Q_R_4, X_R_4)
Y_R_SENSOR4_aug4, X_R_SENSOR4_aug4 = tsaug.Convolve(window="flat", size=5).augment(Y_Q_R_4, X_R_4)

#Drift
Y_R_SENSOR4_aug5, X_R_SENSOR4_aug5 = tsaug.Drift(max_drift=0.3, n_drift_points=5).augment(Y_Q_R_4, X_R_4)
Y_R_SENSOR4_aug6, X_R_SENSOR4_aug6 = tsaug.Drift(max_drift=0.5, n_drift_points=5).augment(Y_Q_R_4, X_R_4)

Y_R_SENSOR4_aug7, X_R_SENSOR4_aug7 = tsaug.Drift(max_drift=0.3, n_drift_points=5).augment(Y_Q_R_4, X_R_4)
Y_R_SENSOR4_aug8, X_R_SENSOR4_aug8 = tsaug.Drift(max_drift=0.3, n_drift_points=3).augment(Y_Q_R_4, X_R_4)

#Quantize
Y_R_SENSOR4_aug9, X_R_SENSOR4_aug9 = tsaug.Quantize(n_levels=10).augment(Y_Q_R_4, X_R_4)
Y_R_SENSOR4_aug10, X_R_SENSOR4_aug10 = tsaug.Quantize(n_levels=20).augment(Y_Q_R_4, X_R_4)

# %%
df1 = df2 = df3 = df4 = df5 = df6 = df7 = df8 = df9 = df10 = df.copy()

# %%
df1['Q_I_1'] = Y_I_SENSOR1_aug1
df1['Q_J_1'] = Y_J_SENSOR1_aug1
df1['Q_K_1'] = Y_K_SENSOR1_aug1
df1['Q_R_1'] = Y_R_SENSOR1_aug1 
#######################################################################
df1['Q_I_2'] = Y_I_SENSOR2_aug1
df1['Q_J_2'] = Y_J_SENSOR2_aug1
df1['Q_K_2'] = Y_K_SENSOR2_aug1
df1['Q_R_2'] = Y_R_SENSOR2_aug1

########################################################################

df1['Q_I_3'] = Y_I_SENSOR3_aug1
df1['Q_J_3'] = Y_J_SENSOR3_aug1
df1['Q_K_3'] = Y_K_SENSOR3_aug1
df1['Q_R_3'] = Y_R_SENSOR3_aug1
########################################################################
df1['Q_I_4'] = Y_I_SENSOR4_aug1
df1['Q_J_4'] = Y_J_SENSOR4_aug1
df1['Q_K_4'] = Y_K_SENSOR4_aug1
df1['Q_R_4'] = Y_R_SENSOR4_aug1

# %%
df2['Q_I_1'] = Y_I_SENSOR1_aug2
df2['Q_J_1'] = Y_J_SENSOR1_aug2
df2['Q_K_1'] = Y_K_SENSOR1_aug2
df2['Q_R_1'] = Y_R_SENSOR1_aug2
#######################################################################
df2['Q_I_2'] = Y_I_SENSOR2_aug2
df2['Q_J_2'] = Y_J_SENSOR2_aug2
df2['Q_K_2'] = Y_K_SENSOR2_aug2
df2['Q_R_2'] = Y_R_SENSOR2_aug2

########################################################################

df2['Q_I_3'] = Y_I_SENSOR3_aug2
df2['Q_J_3'] = Y_J_SENSOR3_aug2
df2['Q_K_3'] = Y_K_SENSOR3_aug2
df2['Q_R_3'] = Y_R_SENSOR3_aug2
########################################################################
df2['Q_I_4'] = Y_I_SENSOR4_aug2
df2['Q_J_4'] = Y_J_SENSOR4_aug2
df2['Q_K_4'] = Y_K_SENSOR4_aug2
df2['Q_R_4'] = Y_R_SENSOR4_aug2

# %%
df3['Q_I_1'] = Y_I_SENSOR1_aug3
df3['Q_J_1'] = Y_J_SENSOR1_aug3
df3['Q_K_1'] = Y_K_SENSOR1_aug3
df3['Q_R_1'] = Y_R_SENSOR1_aug3 
#######################################################################
df3['Q_I_2'] = Y_I_SENSOR2_aug3
df3['Q_J_2'] = Y_J_SENSOR2_aug3
df3['Q_K_2'] = Y_K_SENSOR2_aug3
df3['Q_R_2'] = Y_R_SENSOR2_aug3

########################################################################

df3['Q_I_3'] = Y_I_SENSOR3_aug3
df3['Q_J_3'] = Y_J_SENSOR3_aug3
df3['Q_K_3'] = Y_K_SENSOR3_aug3
df3['Q_R_3'] = Y_R_SENSOR3_aug3
########################################################################
df3['Q_I_4'] = Y_I_SENSOR4_aug3
df3['Q_J_4'] = Y_J_SENSOR4_aug3
df3['Q_K_4'] = Y_K_SENSOR4_aug3
df3['Q_R_4'] = Y_R_SENSOR4_aug3

# %%
df4['Q_I_1'] = Y_I_SENSOR1_aug4
df4['Q_J_1'] = Y_J_SENSOR1_aug4
df4['Q_K_1'] = Y_K_SENSOR1_aug4
df4['Q_R_1'] = Y_R_SENSOR1_aug4
#######################################################################
df4['Q_I_2'] = Y_I_SENSOR2_aug4
df4['Q_J_2'] = Y_J_SENSOR2_aug4
df4['Q_K_2'] = Y_K_SENSOR2_aug4
df4['Q_R_2'] = Y_R_SENSOR2_aug4

########################################################################

df4['Q_I_3'] = Y_I_SENSOR3_aug4
df4['Q_J_3'] = Y_J_SENSOR3_aug4
df4['Q_K_3'] = Y_K_SENSOR3_aug4
df4['Q_R_3'] = Y_R_SENSOR3_aug4
########################################################################
df4['Q_I_4'] = Y_I_SENSOR4_aug4
df4['Q_J_4'] = Y_J_SENSOR4_aug4
df4['Q_K_4'] = Y_K_SENSOR4_aug4
df4['Q_R_4'] = Y_R_SENSOR4_aug4

# %%
df5['Q_I_1'] = Y_I_SENSOR1_aug5
df5['Q_J_1'] = Y_J_SENSOR1_aug5
df5['Q_K_1'] = Y_K_SENSOR1_aug5
df5['Q_R_1'] = Y_R_SENSOR1_aug5
#######################################################################
df5['Q_I_2'] = Y_I_SENSOR2_aug5
df5['Q_J_2'] = Y_J_SENSOR2_aug5
df5['Q_K_2'] = Y_K_SENSOR2_aug5
df5['Q_R_2'] = Y_R_SENSOR2_aug5

########################################################################

df5['Q_I_3'] = Y_I_SENSOR3_aug5
df5['Q_J_3'] = Y_J_SENSOR3_aug5
df5['Q_K_3'] = Y_K_SENSOR3_aug5
df5['Q_R_3'] = Y_R_SENSOR3_aug5
########################################################################
df5['Q_I_4'] = Y_I_SENSOR4_aug5
df5['Q_J_4'] = Y_J_SENSOR4_aug5
df5['Q_K_4'] = Y_K_SENSOR4_aug5
df5['Q_R_4'] = Y_R_SENSOR4_aug5

# %%
df6['Q_I_1'] = Y_I_SENSOR1_aug6
df6['Q_J_1'] = Y_J_SENSOR1_aug6
df6['Q_K_1'] = Y_K_SENSOR1_aug6
df6['Q_R_1'] = Y_R_SENSOR1_aug6 
#######################################################################
df6['Q_I_2'] = Y_I_SENSOR2_aug6
df6['Q_J_2'] = Y_J_SENSOR2_aug6
df6['Q_K_2'] = Y_K_SENSOR2_aug6
df6['Q_R_2'] = Y_R_SENSOR2_aug6

########################################################################

df6['Q_I_3'] = Y_I_SENSOR3_aug6
df6['Q_J_3'] = Y_J_SENSOR3_aug6
df6['Q_K_3'] = Y_K_SENSOR3_aug6
df6['Q_R_3'] = Y_R_SENSOR3_aug6
########################################################################
df6['Q_I_4'] = Y_I_SENSOR4_aug6
df6['Q_J_4'] = Y_J_SENSOR4_aug6
df6['Q_K_4'] = Y_K_SENSOR4_aug6
df6['Q_R_4'] = Y_R_SENSOR4_aug6

# %%
df7['Q_I_1'] = Y_I_SENSOR1_aug7
df7['Q_J_1'] = Y_J_SENSOR1_aug7
df7['Q_K_1'] = Y_K_SENSOR1_aug7
df7['Q_R_1'] = Y_R_SENSOR1_aug7
#######################################################################
df7['Q_I_2'] = Y_I_SENSOR2_aug7
df7['Q_J_2'] = Y_J_SENSOR2_aug7
df7['Q_K_2'] = Y_K_SENSOR2_aug7
df7['Q_R_2'] = Y_R_SENSOR2_aug7

########################################################################

df7['Q_I_3'] = Y_I_SENSOR3_aug7
df7['Q_J_3'] = Y_J_SENSOR3_aug7
df7['Q_K_3'] = Y_K_SENSOR3_aug7
df7['Q_R_3'] = Y_R_SENSOR3_aug7
########################################################################
df7['Q_I_4'] = Y_I_SENSOR4_aug7
df7['Q_J_4'] = Y_J_SENSOR4_aug7
df7['Q_K_4'] = Y_K_SENSOR4_aug7
df7['Q_R_4'] = Y_R_SENSOR4_aug7

# %%
df8['Q_I_1'] = Y_I_SENSOR1_aug8
df8['Q_J_1'] = Y_J_SENSOR1_aug8
df8['Q_K_1'] = Y_K_SENSOR1_aug8
df8['Q_R_1'] = Y_R_SENSOR1_aug8
#######################################################################
df8['Q_I_2'] = Y_I_SENSOR2_aug8
df8['Q_J_2'] = Y_J_SENSOR2_aug8
df8['Q_K_2'] = Y_K_SENSOR2_aug8
df8['Q_R_2'] = Y_R_SENSOR2_aug8

########################################################################

df8['Q_I_3'] = Y_I_SENSOR3_aug8
df8['Q_J_3'] = Y_J_SENSOR3_aug8
df8['Q_K_3'] = Y_K_SENSOR3_aug8
df8['Q_R_3'] = Y_R_SENSOR3_aug8
########################################################################
df8['Q_I_4'] = Y_I_SENSOR4_aug8
df8['Q_J_4'] = Y_J_SENSOR4_aug8
df8['Q_K_4'] = Y_K_SENSOR4_aug8
df8['Q_R_4'] = Y_R_SENSOR4_aug8

# %%
df9['Q_I_1'] = Y_I_SENSOR1_aug9
df9['Q_J_1'] = Y_J_SENSOR1_aug9
df9['Q_K_1'] = Y_K_SENSOR1_aug9
df9['Q_R_1'] = Y_R_SENSOR1_aug9
#######################################################################
df9['Q_I_2'] = Y_I_SENSOR2_aug9
df9['Q_J_2'] = Y_J_SENSOR2_aug9
df9['Q_K_2'] = Y_K_SENSOR2_aug9
df9['Q_R_2'] = Y_R_SENSOR2_aug9

########################################################################

df9['Q_I_3'] = Y_I_SENSOR3_aug9
df9['Q_J_3'] = Y_J_SENSOR3_aug9
df9['Q_K_3'] = Y_K_SENSOR3_aug9
df9['Q_R_3'] = Y_R_SENSOR3_aug9
########################################################################
df9['Q_I_4'] = Y_I_SENSOR4_aug9
df9['Q_J_4'] = Y_J_SENSOR4_aug9
df9['Q_K_4'] = Y_K_SENSOR4_aug9
df9['Q_R_4'] = Y_R_SENSOR4_aug9

# %%
df10['Q_I_1'] = Y_I_SENSOR1_aug10
df10['Q_J_1'] = Y_J_SENSOR1_aug10
df10['Q_K_1'] = Y_K_SENSOR1_aug10
df10['Q_R_1'] = Y_R_SENSOR1_aug10
#######################################################################
df10['Q_I_2'] = Y_I_SENSOR2_aug10
df10['Q_J_2'] = Y_J_SENSOR2_aug10
df10['Q_K_2'] = Y_K_SENSOR2_aug10
df10['Q_R_2'] = Y_R_SENSOR2_aug10

########################################################################

df10['Q_I_3'] = Y_I_SENSOR3_aug10
df10['Q_J_3'] = Y_J_SENSOR3_aug10
df10['Q_K_3'] = Y_K_SENSOR3_aug10
df10['Q_R_3'] = Y_R_SENSOR3_aug10
########################################################################
df10['Q_I_4'] =  Y_I_SENSOR4_aug10
df10['Q_J_4'] = Y_J_SENSOR4_aug10
df10['Q_K_4'] = Y_K_SENSOR4_aug10
df10['Q_R_4'] = Y_R_SENSOR4_aug10

# %%
df1.to_csv('dataset_agumentation/seated_aug/seated_aug91.csv',index=False) 
df2.to_csv('dataset_agumentation/seated_aug/seated_aug92.csv',index=False) 
df3.to_csv('dataset_agumentation/seated_aug/seated_aug93.csv',index=False) 
df4.to_csv('dataset_agumentation/seated_aug/seated_aug94.csv',index=False) 
df5.to_csv('dataset_agumentation/seated_aug/seated_aug95.csv',index=False) 
df6.to_csv('dataset_agumentation/seated_aug/seated_aug96.csv',index=False) 
df7.to_csv('dataset_agumentation/seated_aug/seated_aug97.csv',index=False) 
df8.to_csv('dataset_agumentation/seated_aug/seated_aug98.csv',index=False) 
df9.to_csv('dataset_agumentation/seated_aug/seated_aug99.csv',index=False) 
df10.to_csv('dataset_agumentation/seated_aug/seated_aug100.csv',index=False)
